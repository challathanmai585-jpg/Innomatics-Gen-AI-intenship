# %% [markdown]
# ## Problem 1: Social Media – Post Engagement Analyzer
# - Problem Statement
# - Create a function to analyze engagement on a social media post.
# ## Rules
# - Calculate total likes
# - If Total Likes ≥ 1000 → Viral Post
# - Otherwise → Normal Engagement
# - Real-Time Use
# - Social media analytics platforms
# - Marketing dashboards
# - Hint
# - Use function
# - Use loop for calculations
# - Expected Output Format
# - Total Likes: 1050
# - Post Status: Viral Post

# %%
def analyze_post_engagement(likes_list):
    # total likes
    total_likes = 0
    
    # likes list and sum them
    for likes in likes_list:
        total_likes += likes
    
    # post status
    if total_likes >= 1000:
        status = "Viral Post"
    else:
        status = "Normal Engagement"
    
    # Print results
    print(f"Total Likes: {total_likes}")
    print(f"Post Status: {status}")



likes_data = [120, 300, 250, 380]  # likes from different sources
analyze_post_engagement(likes_data)
# Out:
# Total Likes: 1050
# Post Status: Viral Post

# %% [markdown]
# # Problem 2: Healthcare – Medicine Stock Alert System
# - Problem Statement
# - Create a function to monitor medicine stock levels.
# - Rules
# - Stock < 10 → Low Stock Alert
# - Stock ≥ 10 → Stock Sufficient
# - Real-Time Use
# - Pharmacy management systems
# - Hospital inventory tracking
# - Hint
# - Use function
# - Use conditional logic
# - Expected Output Format
# - Medicine Stock: 6
# - Status: Low Stock Alert

# %%
def medicine_stock_alert(stock_level):
    if stock_level < 10:
        status = "Low Stock Alert"
    else:
        status = "Stock Sufficient"
    
    print(f"Medicine Stock: {stock_level}")
    print(f"Status: {status}")

medicine_stock_alert(6)
# Out:
# Medicine Stock: 6
# Status: Low Stock Alert

# %% [markdown]
# # Problem 3: Agriculture – Rainfall Adequacy Checker
# - Problem Statement
# - Create a function that analyzes seasonal rainfall data.
# - Rules
# - Calculate average rainfall
# - Average ≥ required level → Adequate Rainfall
# - Otherwise → Inadequate Rainfall
# - Real-Time Use
# - Climate monitoring systems
# - Irrigation planning tools
# - Hint
# - Use function
# - Use loop and math operations
# - Expected Output Format
# - Average Rainfall: 72
# - Rainfall Status: Adequate Rainfall

# %%
def rainfall_adequacy_checker(rainfall_data, required_level):
    # Step 1: Initialize total rainfall
    total_rainfall = 0
    
    # Step 2: Loop through rainfall data and sum values
    for rainfall in rainfall_data:
        total_rainfall += rainfall
    
    # Step 3: Calculate average rainfall
    average_rainfall = total_rainfall / len(rainfall_data)
    
    # Step 4: Determine adequacy
    if average_rainfall >= required_level:
        status = "Adequate Rainfall"
    else:
        status = "Inadequate Rainfall"
    
    print(f"Average Rainfall: {int(average_rainfall)}")
    print(f"Rainfall Status: {status}")

rainfall_data = [80, 65, 70, 73]   # seasonal rainfall values
required_level = 70                # threshold for adequacy
rainfall_adequacy_checker(rainfall_data, required_level)
# Out:
# Average Rainfall: 72
# Rainfall Status: Adequate Rainfall

# %% [markdown]
# ## Problem 4: Social Media – Duplicate Account Detection
# - Problem Statement
# - Create a function to detect duplicate usernames in a system.
# - Rules
# - If duplicates exist → Flag accounts
# - Else → Accounts are unique
# - Real-Time Use
# - Platform moderation
# - Fraud detection systems
# - Hint
# - Use function
# - Use set data structure
# - Expected Output Format
# - Duplicate Accounts Found: Yes

# %%
def detect_duplicate_accounts(usernames):
    # Step 1: Convert list to set to remove duplicates
    unique_usernames = set(usernames)
    #  Compare lengths
    if len(unique_usernames) < len(usernames):
        status = "Yes"
    else:
        status = "No"
    #  Print results
    print(f"Duplicate Accounts Found: {status}")
usernames_list = ["alice", "bob", "charlie", "alice", "david"]
detect_duplicate_accounts(usernames_list)
# Out:
# Duplicate Accounts Found: Yes

# %% [markdown]
# ## Problem 5: Healthcare – Appointment Eligibility Checker
# - Problem Statement
# - Create a function to check whether a patient is eligible for an - -
# - appointment slot.
# - Rules
# - Age ≥ 18 → Eligible
# - Age < 18 → Not Eligible
# - Real-Time Use
# - Hospital appointment systems
# - Healthcare portals
# - Hint
# - Use function
# - Use condition checks
# - Expected Output Format
# - Patient Age: 21
# - Eligibility Status: Eligible

# %%
def appointment_eligibility_checker(age):
    if age >= 18:
        status = "Eligible"
    else:
        status = "Not Eligible"
    print(f"Patient Age: {age}")
    print(f"Eligibility Status: {status}")
appointment_eligibility_checker(21)
# Out:
# Patient Age: 21
# Eligibility Status: Eligible

# %% [markdown]
# ## Problem 6: Agriculture – Premium Crop Price Filter
# - Problem Statement
# - Create a function that filters crop prices above a premium threshold.
# - Rules
# - Price > ₹2000 → Premium Crop
# - Else → Regular Crop
# - Real-Time Use
# - Market analytics
# - Export pricing systems
# - Hint
# - Use function
# - Use list filtering logic
# - Expected Output Format
# - Premium Crops: [2500, 3200]

# %%
def premium_crop_filter(prices, threshold=2000):
    # Step 1: Filter premium crops using list comprehension
    premium_crops = [price for price in prices if price > threshold]
    
    # Step 2: Print results
    print(f"Premium Crops: {premium_crops}")
crop_prices = [1500, 2500, 1800, 3200, 2000]
premium_crop_filter(crop_prices)
# Out:
# Premium Crops: [2500, 3200]

# %% [markdown]
# # Problem 7: System Monitoring – Application Health Checker
# - Problem Statement
# - Create a function to evaluate application health based on error count.
# - Rules
# - Errors = 0 → Healthy
# - Errors ≤ 5 → Minor Issues
# - Errors > 5 → Critical Issues
# - Real-Time Use
# - System monitoring tools
# - IT operations dashboards
# - Hint
# - Use function
# - Use conditional statements
# - Expected Output Format
# - Error Count: 7
# - System Status: Critical Issues

# %%
def application_health_checker(error_count):
    #  Check system status based on error count
    if error_count == 0:
        status = "Healthy"
    elif error_count <= 5:
        status = "Minor Issues"
    else:
        status = "Critical Issues"
    # Print results
    print(f"Error Count: {error_count}")
    print(f"System Status: {status}")
application_health_checker(7)
# Out:
# Error Count: 7
# System Status: Critical Issues

# %% [markdown]
# # Problem 8: Banking – Daily Transaction Limit Checker
# - Problem Statement
# - Create a function to validate daily transaction amount.
# - Rules
# - Daily limit = ₹50,000
# - Amount within limit → Approved
# - Amount exceeds limit → Rejected
# - Real-Time Use
# - Banking systems
# - Fraud prevention systems
# - Hint
# - Use function
# - Use conditional logic
# - Expected Output Format
# - Transaction Amount: 60000
# - Transaction Status: Rejected

# %%
def transaction_limit_checker(amount, daily_limit=50000):
    #  Check transaction status
    if amount <= daily_limit:
        status = "Approved"
    else:
        status = "Rejected"
    
    print(f"Transaction Amount: {amount}")
    print(f"Transaction Status: {status}")
transaction_limit_checker(60000)
# Out:
# Transaction Amount: 60000
# Transaction Status: Rejected

# %% [markdown]
# # Problem 9: E-Learning – Student Attendance Eligibility System
# - Problem Statement
# - Create a function to calculate attendance percentage and check exam eligibility.
# - Rules
# - Attendance ≥ 75% → Eligible
# - Attendance < 75% → Not Eligible
# - Real-Time Use
# - Learning management systems
# - Internship tracking platforms
# - Hint
# - Use function
# - Use list and loop
# - Expected Output Format
# - Attendance Percentage: 80.0
# - Exam Eligibility: Eligible

# %%
def attendance_eligibility(attendance_records, total_classes):
    # Count attended classes using loop
    attended = 0
    for record in attendance_records:
        if record == "Present":
            attended += 1
     #  Calculate attendance percentage
    attendance_percentage = (attended / total_classes) * 100
    # Check eligibility
    if attendance_percentage >= 75:
        status = "Eligible"
    else:
        status = "Not Eligible"

    print(f"Attendance Percentage: {attendance_percentage:.1f}")
    print(f"Exam Eligibility: {status}")

attendance_data = ["Present", "Absent", "Present", "Present", "Present"]
total_classes = 5
attendance_eligibility(attendance_data, total_classes)
# Out:
# Attendance Percentage: 80.0
# Exam Eligibility: Eligible

# %% [markdown]
# # Problem 10: Smart Electricity Bill Analyzer
# - Problem Statement
# - You are building a smart electricity billing system for residential users.
# - Create a function that calculates the electricity bill and classifies usage level based on units consumed.
# - Billing Rules
# - First 100 units → ₹3 per unit
# - Next 100 units (101–200) → ₹5 per unit
# - Above 200 units → ₹7 per unit
# - Usage Classification
# - Total bill < ₹500 → Low Usage
# - ₹500 – ₹1500 → Moderate Usage
# - ₹1500 → High Usage
# - Real-Time Use
# - Smart meter systems
# - Electricity board billing software
# - Energy consumption analytics
# - Hint
# - Use function to calculate bill
# - Use conditional logic for slabs
# - Use return values (bill and usage status)

# %%
def electricity_bill_analyzer(units):
    # Calculate bill based on slabs
    if units <= 100:
        bill = units * 3
    elif units <= 200:
        bill = (100 * 3) + ((units - 100) * 5)
    else:
        bill = (100 * 3) + (100 * 5) + ((units - 200) * 7)
    if bill < 500:
        status = "Low Usage"
    elif bill <= 1500:
        status = "Moderate Usage"
    else:
        status = "High Usage"
    
    print(f"Units Consumed: {units}")
    print(f"Total Bill: ₹{bill}")
    print(f"Usage Status: {status}")
electricity_bill_analyzer(250)
# Out:
# Units Consumed: 250
# Total Bill: ₹1150
# Usage Status: Moderate Usage
